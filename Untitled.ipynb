# %%
import pandas as pd
df = pd.DataFrame({
    'col1':[1,5,3,4,2,8],
    'col2':[1,7,9,3,3,3]
})
df.plot()
# Out:
# <AxesSubplot:>

# %%
import pandas as pd
df = pd.DataFrame({
    'col1':[1,5,3,4,2,8],
    'col2':[1,7,9,3,3,3]
})
df.plot.scatter('col1','col2', color = 'b', marker = 'x')
# Out:
# <AxesSubplot:xlabel='col1', ylabel='col2'>
